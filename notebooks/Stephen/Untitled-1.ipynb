# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/stephen/Flatiron/Phase2/Project2/Data/combined_clean_data.csv')
df.head()
# Out:
#    Unnamed: 0          id   price_x  grade_x      date_x  yr_built_x  \
# 0           0  7129300520  221900.0        4  2014-10-13        1955
# 1           1  6414100192  538000.0        4  2014-12-09        1951
# 2           2  5631500400  180000.0        3  2015-02-25        1933
# 3           3  2487200875  604000.0        4  2014-12-09        1965
# 4           4  1954400510  510000.0        5  2015-02-18        1987
#
#    yr_renovated_x  floors_1.5  floors_2.0  floors_2.5  ...  view_y  \
# 0             NaN           0           0           0  ...    NONE
# 1          1991.0           0           1           0  ...    NONE
# 2             NaN           0           0           0  ...    NONE
# 3             NaN           0           0           0  ...    NONE
# 4             NaN           0           0           0  ...    NONE
#
#    waterfront  zipcode      lat     long  cat_waterfront  cat_view  \
# 0         NaN    98178  47.5112 -122.257             NaN      NONE
# ...
